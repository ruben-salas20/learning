# %% [markdown]
# Hace poco dejaste tu trabajo para crear una empresa de logística espacial que usa cohetes para entregar carga crítica a colonias bajo demanda. Como aún estás en fase de inicio, te encargas de todo tú mismo, incluido escribir el software para gestionar la compleja programación y sincronización entre distintas colonias espaciales.
#
# Antes de desarrollar un sistema completo de planificación de vuelos y logística de cohetes, quieres crear funciones básicas con el módulo datetime de Python para manejar fechas, horas y duraciones. Estas funciones son esenciales para tu servicio de entregas con cohete. En este proyecto, crearás funciones simples y reutilizables para trabajar con marcas de tiempo, calcular tiempos de aterrizaje del cohete a partir del lanzamiento y la duración del viaje, y averiguar cuántos días faltan para una fecha límite de entrega para mantener a tus clientes informados.
#
# Este proyecto no incluye datos, pero puedes probar tus funciones llamándolas en el espacio de trabajo y pasándoles las variables necesarias.

# %%
# Re-run this cell
from datetime import datetime, timedelta

# %%
# Start coding here. Use as many cells as you need.
def format_date(timestamp, datetime_format):
    date = datetime.fromtimestamp(timestamp)
    return date.strftime(datetime_format)

def calculate_landing_time(rocket_launch_dt, travel_duration):
    days = timedelta(days= travel_duration)
    date = rocket_launch_dt + days
    return date.strftime('%d-%m-%Y')

def days_until_delivery(expected_delivery_dt, current_dt):
    delta = expected_delivery_dt - current_dt
    return delta.days

print(format_date(1514665153, "%d-%m-%Y"))
print('\n' + '=' * 20 + '\n')
print(calculate_landing_time(datetime(2023, 2, 15), 20))
print('\n' + '=' * 20 + '\n')
print(days_until_delivery(datetime(2023, 2, 15), datetime(2023, 2, 5)))
# Out:
# 30-12-2017
#
# ...
#
# 07-03-2023
#
# ...
#
# 10
